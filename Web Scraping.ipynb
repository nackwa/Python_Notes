# %%
a=14
a
# Out:
# 14

# %%
from randomuser import RandomUser
import pandas as pd

rm = RandomUser()
data = rm.generate_users(14)
# Convert the list of user dictionaries to a pandas DataFrame
df = pd.DataFrame(data)

# Now 'df' contains the random user data for 5 users
pd.DataFrame(data)
# Out:
#                                                    0
# 0   <randomuser.RandomUser object at 0x7f85601cb7c0>
# 1   <randomuser.RandomUser object at 0x7f85601cba90>
# 2   <randomuser.RandomUser object at 0x7f85601cb880>
# 3   <randomuser.RandomUser object at 0x7f85601cb5e0>
# 4   <randomuser.RandomUser object at 0x7f85601cb040>
# 5   <randomuser.RandomUser object at 0x7f856026b850>
# 6   <randomuser.RandomUser object at 0x7f856026ba00>
# 7   <randomuser.RandomUser object at 0x7f8560124280>
# 8   <randomuser.RandomUser object at 0x7f8560125990>
# 9   <randomuser.RandomUser object at 0x7f8560125c60>
# 10  <randomuser.RandomUser object at 0x7f855bf49990>
# 11  <randomuser.RandomUser object at 0x7f85601ac4f0>
# 12  <randomuser.RandomUser object at 0x7f85601adf60>
# 13  <randomuser.RandomUser object at 0x7f85601acb50>

# %%
name = rm.get_full_name()

name
# Out:
# 'Roy Torres'

# %%
from randomuser import RandomUser
import pandas as pd
import requests

rm = RandomUser()
data = rm.generate_users(14)
# Convert the list of user dictionaries to a pandas DataFrame

name = rm.get_full_name(10)

for user in data:
    print(user.get_full_name(),"", user.get_email())
# Out:
# Bella Fykse  bella.fykse@example.com
# آوا قاسمی  aw.qsmy@example.com
# Gökhan Topaloğlu  gokhan.topaloglu@example.com
# Diane Muller  diane.muller@example.com
# Chloe Lee  chloe.lee@example.com
# Edward Davies  edward.davies@example.com
# Jasmine White  jasmine.white@example.com
# Magnus Rasmussen  magnus.rasmussen@example.com
# Katie Roberts  katie.roberts@example.com
# Karsten Otte  karsten.otte@example.com
# Zara Clarke  zara.clarke@example.com
# رها جعفری  rh.jaafry@example.com
# Silje Koning  silje.koning@example.com
# Laura Duncan  laura.duncan@example.com

# %%
name
# Out:
# 'Roy Torres'

# %%
data = rm.generate_users(14)
data

# %%
from randomuser import RandomUser
import pandas as pd
import requests


r = RandomUser()
some_list = r.generate_users(10)

name = r.get_full_name()

for user in some_list:
    print(user.get_full_name(),"", user.get_email())

for user in some_list:
    print(user.get_picture())
# Out:
# Scarlett Morris  scarlett.morris@example.com
# Amelia Newman  amelia.newman@example.com
# Sarissa Bogaards  sarissa.bogaards@example.com
# Curtis Perkins  curtis.perkins@example.com
# Alexandre Chu  alexandre.chu@example.com
# Franca Morel  franca.morel@example.com
# محمد یاسمی  mhmd.ysmy@example.com
# Daryl Perry  daryl.perry@example.com
# Esha Zweekhorst  esha.zweekhorst@example.com
# Ernesto Silva  ernesto.silva@example.com
# https://randomuser.me/api/portraits/women/32.jpg
# https://randomuser.me/api/portraits/women/15.jpg
# https://randomuser.me/api/portraits/women/88.jpg
# https://randomuser.me/api/portraits/men/50.jpg
# https://randomuser.me/api/portraits/men/83.jpg
# https://randomuser.me/api/portraits/women/87.jpg
# https://randomuser.me/api/portraits/men/25.jpg
# https://randomuser.me/api/portraits/men/70.jpg
# https://randomuser.me/api/portraits/women/25.jpg
# https://randomuser.me/api/portraits/men/56.jpg

# %%
from randomuser import RandomUser
import pandas as pd
import requests

r = RandomUser()
some_list = r.generate_users(10)
name = r.get_full_name()

for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/0.jpg
# https://randomuser.me/api/portraits/women/84.jpg
# https://randomuser.me/api/portraits/men/53.jpg
# https://randomuser.me/api/portraits/men/96.jpg
# https://randomuser.me/api/portraits/men/36.jpg
# https://randomuser.me/api/portraits/men/75.jpg
# https://randomuser.me/api/portraits/men/31.jpg
# https://randomuser.me/api/portraits/women/13.jpg
# https://randomuser.me/api/portraits/men/45.jpg
# https://randomuser.me/api/portraits/women/1.jpg

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)   

get_users()
# Out:
#                         Name  Gender                 City  \
# 0  Leonarda Niemantsverdriet  female         Idsegahuizum
# 1              Saskia Pierre  female             Ossingen
# 2             Rosa Rasmussen  female         Øster Assels
# 3                Pius Ziemer    male   Frankenberg (Eder)
# 4                  Julie Day  female            Edenderry
# 5               Venla Makela  female              Kempele
# 6             Cindy Williams  female               Surrey
# 7                  Gesa Loth  female            Havelland
# 8               Paul Lecomte    male  Champigny-sur-Marne
# 9                 سینا کریمی    male            خمینی‌شهر
#
#                     State                                  Email  \
# 0                 Drenthe  leonarda.niemantsverdriet@example.com
# 1  Appenzell Ausserrhoden              saskia.pierre@example.com
# 2                Sjælland             rosa.rasmussen@example.com
# ...

# %%
import os
import json
import requests
import pandas

data = requests.get("https://fruityvice.com/api/fruit/all") 
results = json.loads(data.text)
pandas.DataFrame(results)
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# ...

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# ...

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %%
cal_banana = df2.loc[df2["name"] == 'Banana'] #Amount of calories in banana
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %%
data2 = requests.get("https://cat-fact.herokuapp.com/facts")

# %%
data2
# Out:
# <Response [200]>

# %%
results2 = json.loads(data2.text)

# %%
results2
# Out:
# [{'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008780aac31001185ed05',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-29T20:20:03.844Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e009390aac31001185ed10',
#   'user': '58e007480aac31001185ecef',
#   'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-04T21:20:02.979Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
# ...

# %%
pandas.DataFrame(results2)
# Out:
#                                status                       _id  \
# 0  {'verified': True, 'sentCount': 1}  58e008780aac31001185ed05
# 1  {'verified': True, 'sentCount': 1}  58e009390aac31001185ed10
# 2  {'verified': True, 'sentCount': 1}  588e746706ac2b00110e59ff
# 3  {'verified': True, 'sentCount': 1}  58e008ad0aac31001185ed0c
# 4  {'verified': True, 'sentCount': 1}  58e007cc0aac31001185ecf5
#
#                        user  \
# 0  58e007480aac31001185ecef
# 1  58e007480aac31001185ecef
# 2  588e6e8806ac2b00110e59c3
# 3  58e007480aac31001185ecef
# 4  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Owning a cat can reduce the risk of stroke and...    0   user
# 1  Most cats are lactose intolerant, and milk can...    0   user
# 2  Domestic cats spend about 70 percent of the da...    0   user
# 3  The frequency of a domestic cat's purr is the ...    0   user
# 4  Cats are the most popular pet in the United St...    0   user
#
# ...

# %%
df3 = pd.json_normalize(results2)
df3
# Out:
#                         _id                      user  \
# 0  58e008780aac31001185ed05  58e007480aac31001185ecef
# 1  58e009390aac31001185ed10  58e007480aac31001185ecef
# 2  588e746706ac2b00110e59ff  588e6e8806ac2b00110e59c3
# 3  58e008ad0aac31001185ed0c  58e007480aac31001185ecef
# 4  58e007cc0aac31001185ecf5  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Owning a cat can reduce the risk of stroke and...    0   user
# 1  Most cats are lactose intolerant, and milk can...    0   user
# 2  Domestic cats spend about 70 percent of the da...    0   user
# 3  The frequency of a domestic cat's purr is the ...    0   user
# 4  Cats are the most popular pet in the United St...    0   user
#
#                   updatedAt type                 createdAt  deleted   used  \
# 0  2020-08-23T20:20:01.611Z  cat  2018-03-29T20:20:03.844Z    False  False
# 1  2020-08-23T20:20:01.611Z  cat  2018-03-04T21:20:02.979Z    False  False
# ...
